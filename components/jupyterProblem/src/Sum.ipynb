# %% [markdown]
# ## Create the function sum() that accepts two parameters and returns the sum of them.

# %%
#def sum

# %% [markdown]
# ## Do not edit any code below this point. These are the tests to validate your function.

# %%
try:
  assert(sum(2,2) == 4)
  assert(sum(2,1) == 3)
except:
  print("One of the tests failed.")
